# %% [markdown]
# ## 練習時間
# 相信大家對回歸問題及分類問題都有初步的了解。今天的作業希望大家搜尋有關 multi-label 的案例問題。下圖是電影 "奇異博士" 的分類。可以看到同時有 "Action", "Adventure", "Fantasy" 的類別存在，代表這是個多標籤的問題。

# %% [markdown]
# ![image](https://cdn-images-1.medium.com/max/1000/1*r0gYXMSQf5VhdMyl2bRDyg.png)

# %% [markdown]
# ## 請搜尋目標為多標籤問題 (Multi-label) 的機器學習案例，了解其資料來源、目標以及評估指標為何
# ## Hint: 服飾

# %%
from google.colab.patches import cv2_imshow
import cv2

# !curl -o multi-label.png https://www.researchgate.net/profile/Tomasz_Kajdanowicz/publication/236657980/figure/fig2/AS:669100443439124@1536537385918/Classification-based-on-all-pairs-encoding-ECOC-and-binary-relevance-multi-label.png

img = cv2.imread('multi-label.png', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=690x778 at 0x7FD456105278>
