# %% [markdown]
# ## [作業重點]
# 清楚了解 L1, L2 的意義與差異為何，並了解 LASSO 與 Ridge 之間的差異與使用情境

# %% [markdown]
# ## 作業

# %% [markdown]
# 請閱讀相關文獻，並回答下列問題
#
# * [脊回歸 (Ridge Regression)](https://blog.csdn.net/daunxx/article/details/51578787)
# * [Linear, Ridge, Lasso Regression 本質區別](https://www.zhihu.com/question/38121173)

# %% [markdown]
# # 1. LASSO 回歸可以被用來作為 Feature selection 的工具，請了解 LASSO 模型為什麼可用來作 Feature selection。

# %% [markdown]
# * 普通最小平方法 (最小二乘解) (Ordinary least squares method，OLS)
#   * 最小平方法（least squares method）

# %%
from google.colab.patches import cv2_imshow
import cv2

# !curl -o variable.jpg https://i.pinimg.com/736x/ea/08/8a/ea088aec8952b49eedd7cf16b58cd283--linear-regression-machine-learning.jpg
variable = cv2.imread('variable.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(variable)
# Out:
# <PIL.Image.Image image mode=RGB size=728x546 at 0x7FBB7E100438>

# %% [markdown]
# *「正規化回歸 regularized regression」(又稱作penalized models或shrinkage method)
#
#     正規化回歸模型會對回歸係數大小做出約束，並逐漸的將回歸係數壓縮到零。而對回歸係數的限制將有助於降低係數的幅度和波動，並降低模型的變異。
#   * 正規化回歸的目標函式與OLS回歸類似，但多了一個懲罰參數(penalty parameter, P)： minimize{ SSE + P }
#
#     * 懲罰係數將會限制回歸係數的大小，使誤差平方和(SSE)降低。
#
#   *  L1 Penalty (Lasso，Least absolute shrinkage and selection operator)
#       *
# minimize { SSE + $ λ \sum_{j=1}^{p}{|βj|}$ }
#
#   *  L2 Penalty (Ridge Regression)
#       *
# minimize { SSE + $ λ \sum_{j=1}^{p}{ βj^{2} }$ }

# %%
# !curl -o Penalty.png https://pic3.zhimg.com/50/v2-2a88e2acc009fa4de3edeb51e683ca02_r.jpg
Penalty = cv2.imread('Penalty.png', cv2.IMREAD_UNCHANGED)
cv2_imshow(Penalty)
# Out:
# <PIL.Image.Image image mode=RGB size=602x399 at 0x7FBB9057A5C0>

# %% [markdown]
# * Feature selection
#  * Lasso模型則會將係數推進成 0
#  * 當在log(λ)越大時，變數被保留在模型內越少

# %%
# !curl -o lasso.png https://www.jamleecute.com/wp-content/uploads/2019/01/unnamed-chunk-194-1.png
lasso = cv2.imread('lasso.png', cv2.IMREAD_UNCHANGED)
cv2_imshow(lasso)
# Out:
# <PIL.Image.Image image mode=RGBA size=504x504 at 0x7FBB7E1002E8>

# %% [markdown]
# # 2. 當自變數 (X) 存在高度共線性時，Ridge Regression 可以處理這樣的問題嗎?

# %% [markdown]
# * Ridge Regression 可以將 feature影響降低，但不會歸零。
#  會造成計算爆炸。

# %%
# !curl -o  Ridge.png https://www.jamleecute.com/wp-content/uploads/2019/01/unnamed-chunk-177-1.png
Ridge = cv2.imread('Ridge.png', cv2.IMREAD_UNCHANGED)
cv2_imshow(Ridge)
# Out:
# <PIL.Image.Image image mode=RGBA size=504x504 at 0x7FBB7E168C50>

# %%
# shrinkage

# !curl -o  shrinkage.png https://www.jamleecute.com/wp-content/uploads/2019/01/unnamed-chunk-204-1.png
shrinkage = cv2.imread('shrinkage.png', cv2.IMREAD_UNCHANGED)
cv2_imshow(shrinkage)
# Out:
# <PIL.Image.Image image mode=RGBA size=504x504 at 0x7FBB7E100320>
