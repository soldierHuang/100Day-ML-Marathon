# %% [markdown]
# # 作業 : (Kaggle)房價預測

# %% [markdown]
# # [作業目標]
# - 試著模仿範例寫法, 在房價預測中, 觀察去除離群值的影響

# %% [markdown]
# # [作業重點]
# - 觀察將極端值以上下限值取代, 對於分布與迴歸分數的影響 (In[5], Out[5])
# - 觀察將極端值資料直接刪除, 對於分布與迴歸分數的影響 (In[6], Out[6])

# %%
# 做完特徵工程前的所有準備 (與前範例相同)
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

# 讀取訓練與測試資料
# !wget http://ai100.cupoy.com/file-download/part02/house_test.csv.gz
# !wget http://ai100.cupoy.com/file-download/part02/house_train.csv.gz

data_path = './'
df_train = pd.read_csv(data_path + 'house_train.csv.gz')

train_Y = np.log1p(df_train['SalePrice'])
df = df_train.drop(['Id', 'SalePrice'] , axis=1)
df.head()
# Out:
# --2019-12-05 08:57:14--  http://ai100.cupoy.com/file-download/part02/house_test.csv.gz
# Resolving ai100.cupoy.com (ai100.cupoy.com)... 13.224.29.103, 13.224.29.66, 13.224.29.82, ...
# Connecting to ai100.cupoy.com (ai100.cupoy.com)|13.224.29.103|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83948 (82K) [application/x-gzip]
# Saving to: ‘house_test.csv.gz.1’
#
# house_test.csv.gz.1 100%[===================>]  81.98K  --.-KB/s    in 0.01s
#
# 2019-12-05 08:57:14 (6.29 MB/s) - ‘house_test.csv.gz.1’ saved [83948/83948]
#
# --2019-12-05 08:57:16--  http://ai100.cupoy.com/file-download/part02/house_train.csv.gz
# Resolving ai100.cupoy.com (ai100.cupoy.com)... 13.224.29.103, 13.224.29.66, 13.224.29.82, ...
# Connecting to ai100.cupoy.com (ai100.cupoy.com)|13.224.29.103|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 91387 (89K) [application/x-gzip]
# Saving to: ‘house_train.csv.gz.1’
#
# house_train.csv.gz. 100%[===================>]  89.25K  --.-KB/s    in 0.01s
#
# 2019-12-05 08:57:16 (6.60 MB/s) - ‘house_train.csv.gz.1’ saved [91387/91387]
#    MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0          60       RL         65.0  ...    2008       WD        Normal
# 1          20       RL         80.0  ...    2007       WD        Normal
# 2          60       RL         68.0  ...    2008       WD        Normal
# 3          70       RL         60.0  ...    2006       WD       Abnorml
# 4          60       RL         84.0  ...    2008       WD        Normal
#
# [5 rows x 79 columns]

# %%
#只取 int64, float64 兩種數值型欄位, 存於 num_features 中
num_features = []
for dtype, feature in zip(df.dtypes, df.columns):
    if dtype == 'float64' or dtype == 'int64':
        num_features.append(feature)
print(f'{len(num_features)} Numeric Features : {num_features}\n')
# Out:
# 36 Numeric Features : ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %%
# 削減文字型欄位, 只剩數值型欄位
df = df[num_features]
df = df.fillna(-1)
MMEncoder = MinMaxScaler()
train_num = train_Y.shape[0]
df.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  ...  MiscVal  MoSold  YrSold
# 0          60         65.0     8450  ...        0       2    2008
# 1          20         80.0     9600  ...        0       5    2007
# 2          60         68.0    11250  ...        0       9    2008
# 3          70         60.0     9550  ...        0       2    2006
# 4          60         84.0    14260  ...        0      12    2008
#
# [5 rows x 36 columns]

# %% [markdown]
# # 作業1
# * 試著限制 '1樓地板面積(平方英尺)' (1stFlrSF) 欄位的上下限, 看看能否再進一步提高分數?

# %%
# 顯示 1stFlrSF 與目標值的散佈圖
import seaborn as sns
import matplotlib.pyplot as plt
sns.regplot(x = df['1stFlrSF'][:train_num], y=train_Y)
plt.show()

# 做線性迴歸, 觀察分數
train_X = MMEncoder.fit_transform(df)
estimator = LinearRegression()
cross_val_score(estimator, train_X, train_Y, cv=5).mean()
# Out:
# 0.8466046274204875

# %% [markdown]
# # Boxplot法

# %%
print( "眾數 mode: ",df["1stFlrSF"].mode() )
print( df["1stFlrSF"].describe() )
df["1stFlrSF"].plot(kind='box', vert=False)
# Out:
# 眾數 mode:  0    864
# dtype: int64
# count    1460.000000
# mean     1162.626712
# std       386.587738
# min       334.000000
# 25%       882.000000
# 50%      1087.000000
# 75%      1391.250000
# max      4692.000000
# Name: 1stFlrSF, dtype: float64

# %% [markdown]
#   ![alt text](https://miro.medium.com/max/9000/1*2c21SkzJMf3frPXPAR_gZA.png)
#   https://miro.medium.com/max/9000/1*2c21SkzJMf3frPXPAR_gZA.png

# %%
# 將 1stFlrSF 限制在你覺得適合的範圍內, 調整離群值

df['1stFlrSF'] = df['1stFlrSF'].clip(500, 2200)
sns.regplot(x = df['1stFlrSF'], y=train_Y)
plt.show()


# 做線性迴歸, 觀察分數
train_X = MMEncoder.fit_transform(df)
estimator = LinearRegression()
cross_val_score(estimator, train_X, train_Y, cv=5).mean()
# Out:
# 0.8822361961094198

# %% [markdown]
# # 作業2
# * 續前題, 去除離群值有兩類方式 :  捨棄離群值(刪除離群的資料) 以及調整離群值,
# 請試著用同樣的上下限, 改為 '捨棄離群值' 的方法, 看看結果會變好還是變差? 並試著解釋原因。

# %%
# 將 1stFlrSF 限制在你覺得適合的範圍內, 捨棄離群值
keep_indexs = (df['1stFlrSF']> 499) & (df['1stFlrSF']< 2199)
df = df[keep_indexs]
train_Y = train_Y[keep_indexs]
sns.regplot(x = df['1stFlrSF'], y=train_Y)
plt.show()


# 做線性迴歸, 觀察分數
train_X = MMEncoder.fit_transform(df)
estimator = LinearRegression()
cross_val_score(estimator, train_X, train_Y, cv=5).mean()
# Out:
# 0.8917566136159876

# %% [markdown]
# 調整離群值會使原本的離群值變成上限或下限 數量多少影響結果 捨棄離群直可以較精確地看出資料的分佈 不過卻也有可能誤刪重要訊息
